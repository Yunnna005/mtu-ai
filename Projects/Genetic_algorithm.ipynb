# %% [markdown]
# Air Traffic Control
#
# Chromosome - list of the rules like the hight, distance, altitude of each plane flying in the air avoiding crash.

# %% [markdown]
# ---
# Basic Imports

# %%
import numpy as np
from copy import deepcopy
import array as arr
from datetime import datetime, timedelta
import random

# %% [markdown]
# #### Penalty logic
# 1. Height penalty (any planes that is not exactly 500)
# 1. Safety penalty (planes too close to each other like 40m apart; planes on the same runway at the same time)

# %%
def cost_function(chromosome):
    penalty = 0
    number_of_planes = int(len(chromosome) / 5)

    planes = []

    for i in range(number_of_planes):
        index = i * 5
        time = chromosome[index]
        position = chromosome[index + 1]
        height = chromosome[index + 2]
        runway = chromosome[index + 3]
        side = chromosome[index + 4]

        planes.append([time, position, height, runway, side])

        penalty += abs(height - 500)
        
    for i in range(number_of_planes):
        for j in range(i+1, number_of_planes):

            p1 = planes[i]
            p2 = planes[j]

            distance = abs(p1[1] - p2[1])

            if distance < 40:
                penalty += 10000

            if p1[3] == p2[3] and abs(p1[0] - p2[0]) < 10:
                penalty += 5000

    return penalty

# %% [markdown]
# #### Generate genes with values: timestamp (seconds), position, height, runway, runway side (West/East)

# %%
def generate_genes(num_of_genes):
    num_generations = num_of_genes
    all_genes = []
    base_time = datetime.now()

    for i in range(num_generations):
        time = (base_time + timedelta(seconds=random.randint(0, 3600))).strftime("%S")
        gene = [
            time,  
            random.uniform(0, 2000),                                  
            random.uniform(300, 700),                                 
            random.choice(["RW-1", "RW-2", "RW-3"]),   
            random.choice(["West", "East"])                           
        ]

        all_genes.append(gene)


    return list(all_genes)

# %% [markdown]
# Convert Runway and Map Side to numeric values

# %%
def convert_genes_values(planes):
    chromosome = []

    for plane in planes:
        time = int(plane[0])
        position = plane[1]
        height = plane[2]

        runway_map = {"RW-1":1, "RW-2":2, "RW-3":3}
        side_map = {"West":0, "East":1}

        runway = runway_map[plane[3]]
        side = side_map[plane[4]]

        chromosome.extend([time, position, height, runway, side])

    return np.array(chromosome)

# %%
class problem:
    def __init__(self, number_of_planes):
        self.number_of_planes = number_of_planes
        self.genes_per_plane = 5  
        self.number_of_genes = self.number_of_planes * self.genes_per_plane
        self.cost_function = cost_function

# %%
class Parameters:
    def __init__(self):
        self.population = 400
        self.maximum_number_of_generations = 1000
        self.crossover_exploration = 0.5
        self.mutation_rate = 0.2
        self.mutation_range = 2.0
        self.child_factor = 1

# %%
class Individual:
    def __init__(self, prob):
        planes = generate_genes(prob.number_of_planes)
        print("Generated planes:")
        print(planes)

        self.chromosome = convert_genes_values(planes)
        print("Fixed chromosome:")
        print(self.chromosome)

        self.cost = cost_function(self.chromosome)
        print("Cost:")
        print(self.cost)

    def Crossover(self, other, epsilon):
        child1 = deepcopy(self)
        child2 = deepcopy(other)

        alpha = np.random.uniform(-epsilon,1+epsilon)

        child1.chromosome = alpha*self.chromosome + (1-alpha)*other.chromosome
        child2.chromosome = (1-alpha)*self.chromosome + alpha*other.chromosome
        return child1, child2
    
    def Mutate(self,mutation_rate,mutation_range):
        for i in range(len(self.chromosome)):
            if np.random.uniform(0,1) < mutation_rate:
                self.chromosome[i] += np.random.randn()*mutation_range

# %%
def get_parents(population):
    ##logic
    return population

# %%
def run_genetic(prob, params):
    ##logic
    return prob

# %%
prob = problem(number_of_planes=10)
test_individual = Individual(prob)
# Out:
# Generated planes:
# [['45', 1340.1658260335262, 536.1919224616579, 'RW-1', 'East'], ['00', 181.16353971056753, 399.9605614022968, 'RW-2', 'East'], ['00', 294.2161174984996, 397.58166106147723, 'RW-2', 'East'], ['35', 1360.5702168300113, 463.17723205079614, 'RW-3', 'West'], ['29', 593.9877409393339, 478.21087303441453, 'RW-1', 'West'], ['00', 1381.3633935017972, 416.4084840663115, 'RW-1', 'East'], ['05', 1056.8946701036289, 538.1185122218418, 'RW-1', 'West'], ['25', 1822.427661388725, 494.6574232436365, 'RW-3', 'West'], ['57', 1936.5169726377817, 369.9632280172506, 'RW-3', 'West'], ['09', 1638.7115920808621, 353.0669891007537, 'RW-2', 'West']]
# Fixed chromosome:
# [4.50000000e+01 1.34016583e+03 5.36191922e+02 1.00000000e+00
#  1.00000000e+00 0.00000000e+00 1.81163540e+02 3.99960561e+02
#  2.00000000e+00 1.00000000e+00 0.00000000e+00 2.94216117e+02
#  3.97581661e+02 2.00000000e+00 1.00000000e+00 3.50000000e+01
#  1.36057022e+03 4.63177232e+02 3.00000000e+00 0.00000000e+00
#  2.90000000e+01 5.93987741e+02 4.78210873e+02 1.00000000e+00
#  0.00000000e+00 0.00000000e+00 1.38136339e+03 4.16408484e+02
#  1.00000000e+00 1.00000000e+00 5.00000000e+00 1.05689467e+03
#  5.38118512e+02 1.00000000e+00 0.00000000e+00 2.50000000e+01
#  1.82242766e+03 4.94657423e+02 3.00000000e+00 0.00000000e+00
#  5.70000000e+01 1.93651697e+03 3.69963228e+02 3.00000000e+00
#  0.00000000e+00 9.00000000e+00 1.63871159e+03 3.53066989e+02
#  2.00000000e+00 0.00000000e+00]
# Cost:
# 40701.28398270656
